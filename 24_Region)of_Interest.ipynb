# %% [markdown]
# # Region of Interest

# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r"opencv_Images\Screenshot38.png")
img = cv2.resize(img,(700,500))

# %%
cv2.imwrite(r"opencv_Images\notebook24_img.jpg",img)
# Out:
# True

# %%
crop_img = img[148:463,296:402]

# %%
# right side
img[148:463,402:508] = crop_img
img[148:463,508:614] = crop_img

# left side
img[148:463,190:296] = crop_img
img[148:463,84:190] = crop_img

# %%
#cv2.imshow("person",crop_img)
cv2.imshow("addites image",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
