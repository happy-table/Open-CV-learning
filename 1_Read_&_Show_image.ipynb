# %%
import cv2
image = cv2.imread(r"1_img.png")
if image is not None:
    cv2.imshow("IMAGE_1",image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("Could not load image")

# %%
import cv2

image = cv2.imread(
    r"1_img.png"
)

if image is None:
    print("❌ Image not loaded – path issue")
else:
    cv2.imshow("IMAGE 1", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ❌ Image not loaded – path issue

# %%
import os

path = r"1_img.png"
print(os.path.exists(path))
# Out:
# True

# %%
import cv2
import os
list_name = os.listdir(r"images")
list_name
img = cv2.imread(r"id1.png")
print(img)
print(img.shape)
# Out:
# [[[  0   0   0]
#   [252 255 214]
#   [252 255 214]
#   ...
#   [252 255 214]
#   [252 255 214]
#   [252 255 214]]
#
#  [[  0   0   0]
#   [252 255 214]
#   [252 255 214]
#   ...
#   [252 255 214]
#   [252 255 214]
#   [252 255 214]]
#
#  [[  0   0   0]
#   [252 255 214]
#   [252 255 214]
#   ...
#   [252 255 214]
#   [252 255 214]
#   [252 255 214]]
#
#  ...
#
#  [[  0   0   0]
#   [163 207 178]
#   [163 207 178]
#   ...
#   [ 76 119 174]
#   [ 74 116 172]
#   [ 70 111 167]]
#
#  [[  0   0   0]
#   [163 207 178]
#   [163 207 178]
#   ...
#   [ 75 117 172]
#   [ 77 120 175]
#   [ 73 114 170]]
#
#  [[  0   0   0]
#   [163 207 178]
#   [163 207 178]
#   ...
#   [ 76 119 174]
#   [ 76 119 174]
#   [ 71 112 168]]]
# (304, 460, 3)

# %%
import cv2
import os
list_name = os.listdir(r"images")

for name in list_name:
    path = "C:\\Users\\path\\images"
    img_name = path + "//" + name
    img = cv2.imread(img_name ,-1)
    img = cv2.resize(img,(700,600))
    cv2.imshow("child vaccination",img)
    cv2.waitKey(3000)
cv2.destroyAllWindows()
