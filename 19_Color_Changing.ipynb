# %% [markdown]
# # cvtColor method

# %%
primary color : BGR
it is imp because different tasks need different color representations.

# %%
import cv2

# %%
img = cv2.imread(r"opencv_Images\img2.png")
img = cv2.resize(img,(500,500))

# %%
print(img.shape)
# Out:
# (500, 500, 3)

# %%
bgr_immg = cv2.cvtColor(img , cv2.COLOR_GRAY2BGR)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bgr_immg = cv2.cvtColor(img , cv2.COLOR_GRAY2BGR)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.simd_helpers.hpp:92: error: (-15:Bad number of channels) in function '__cdecl cv::impl::`anonymous-namespace'::CvtHelper<struct cv::impl::`anonymous namespace'::Set<1,-1,-1>,struct cv::impl::A0x6f7fe6c3::Set<3,4,-1>,struct cv::impl::A0x6f7fe6c3::Set<0,2,5>,4>::CvtHelper(const class cv::_InputArray &,const class cv::_OutputArray &,int)'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 3

# %%
gray_img = cv2.cvtColor(bgr_img, cv2.COLOR_BGR2GRAY)

# %%
# If you want to detect only red objects → HSV is much better than BGR.
hsv_img = cv2.cvtColor(bgr_img ,cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # If you want to detect only red objects → HSV is much better than BGR.
# ----> 2 hsv_img = cv2.cvtColor(bgr_img ,cv2.COLOR_BGR2HSV)
#
# NameError: name 'cv2' is not defined

# %%
cv2.imshow("orginal bgr image",bgr_img)
cv2.imshow("gray scale image",gray_img)
cv2.imshow("hsv image",hsv_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
